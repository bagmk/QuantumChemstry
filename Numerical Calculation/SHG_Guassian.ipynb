# %%
import numpy as np
import math
import scipy.linalg as la
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # SHO Potential

# %%
N=100
n = list(range(0, N))
s = np.zeros(N)
h = np.zeros((N,N))
o = np.zeros((N,N))
for i in n:
    s[i] = -25.0+ (i)*0.5

for i in n:
    for j in n:
        ss = (s[i]-s[j])**2
        #print(ss)
        o[i][j] = math.exp(-0.5*ss)
        t = math.exp(-0.5*ss)*0.5*(1-ss)
        p = 0.5* math.exp(-0.5*ss)*0.25*(1+(s[i]+s[j])**2)
        h[i][j] = t + p
#print(h) 
#eigvals, eigvecs = np.linalg.eigh(h)
eigvals, eigvecs = la.eigh(h,o)

print(eigvals)
# Out:
# [  0.5          1.5          2.5          3.5          4.5
#    5.5          6.50000001   7.50000016   8.50000021   9.50000722
#   10.50000404  11.50018212  12.500033    13.50268835  14.50006184
#   15.52328013  16.50022873  17.61926636  18.5135903   19.88745245
#   20.6170132   22.40173756  22.94813907  25.18660143  25.58739632
#   28.24209382  28.53909655  31.56327542  31.78668488  35.1457828
#   35.31595417  38.98650478  39.1173575   43.08331352  43.18464147
#   47.43475288  47.51362953  52.03981541  52.10145758  56.89779696
#   56.94611506  62.00820417  62.04616657  67.37069617  67.40057926
#   72.98504829  73.00861459  78.85113011  78.86976126  84.96889205
#   84.98369734  91.33835589  91.3502764   97.95960535  97.96953649
#  104.83278426 104.84172248 111.95814323 111.96728187 119.33615497
#  119.34681667 126.96758119 126.98111399 134.85345873 134.87129578
#  142.9951361  143.01896856 151.39438727 151.42636275 160.05357376
#  160.0965147  168.97585499 169.03352498 178.16546747 178.24292194
#  187.62810451 187.73217197 197.3714421  197.51140237 207.40588039
#  207.59444332 217.74561047 218.00036687 228.41018899 228.75583375
#  239.42693827 239.8988222  250.83475948 251.48487693 262.69052192
#  263.59833977 275.08054566 276.37453604 288.14328459 290.04991468
#  302.12058795 305.10169214 317.50046382 322.82131193 335.60332771]

# %% [markdown]
# # Gaussian Potential

# %%
N=100
n = list(range(0, N))
s = np.zeros(N)
h = np.zeros((N,N))
o = np.zeros((N,N))
urang=[10**((i-15)/15) for i in range(31)]

gsp=[]
gsp1=[]
gsp2=[]
gsp3=[]
gsp4=[]
gsp5=[]
gsp6=[]
gsp7=[]
for u in urang:
    for i in n:
        s[i] = -25.0+ (i)*0.5

    for i in n:
        for j in n:
            ss = (s[i]-s[j])**2
            #print(ss)
            o[i][j] = math.exp(-0.5*ss)
            t = math.exp(-0.5*ss)*0.5*(1-ss)
            p = (2/(2+u)**0.5) *math.exp(-0.5*ss)*math.exp(-((s[i]-s[j])**2+u*s[i]**2+u*s[j]**2)/(2+u))
            h[i][j] = t + p
    #print(h) 
    #eigvals, eigvecs = np.linalg.eigh(h)
    eigvals, eigvecs = la.eigh(h,o)
    gsp.append(eigvecs[0])
    gsp1.append(eigvals[1])
    gsp2.append(eigvals[2])
    gsp3.append(eigvals[3])
    gsp4.append(eigvals[4])
    gsp5.append(eigvals[5])
    gsp6.append(eigvals[6])
    gsp7.append(eigvals[7])

# %%
u=0
for i in n:
    s[i] = -25.0+ (i)*0.5

for i in n:
    for j in n:
        ss = (s[i]-s[j])**2
        #print(ss)
        o[i][j] = math.exp(-0.5*ss)
        t = math.exp(-0.5*ss)*0.5*(1-ss)
        p = (2/(2+u)**0.5) *math.exp(-0.5*ss)*math.exp(-((s[i]-s[j])**2+u*s[i]**2+u*s[j]**2)/(2+u))
        h[i][j] = t + p
#print(h) 
#eigvals, eigvecs = np.linalg.eigh(h)
eigvals, eigvecs = la.eigh(h,o)

# %%
eigvals
# Out:
# array([1.00267604e+00, 1.01070919e+00, 1.02411457e+00, 1.04291756e+00,
#        1.06715399e+00, 1.09687047e+00, 1.13212484e+00, 1.17298667e+00,
#        1.21953788e+00, 1.27187354e+00, 1.33010276e+00, 1.39434966e+00,
#        1.46475464e+00, 1.54147568e+00, 1.62468994e+00, 1.71459548e+00,
#        1.81141331e+00, 1.91538966e+00, 2.02679853e+00, 2.14594467e+00,
#        2.27316684e+00, 2.40884159e+00, 2.55338748e+00, 2.70726992e+00,
#        2.87100661e+00, 3.04517373e+00, 3.23041298e+00, 3.42743956e+00,
#        3.63705127e+00, 3.86013885e+00, 4.09769776e+00, 4.35084170e+00,
#        4.62081790e+00, 4.90902477e+00, 5.21703203e+00, 5.54660373e+00,
#        5.89972481e+00, 6.27863149e+00, 6.68584631e+00, 7.12421847e+00,
#        7.59697037e+00, 8.10775137e+00, 8.66069998e+00, 9.26051589e+00,
#        9.91254349e+00, 1.06228689e+01, 1.13984330e+01, 1.22471627e+01,
#        1.31781244e+01, 1.42017035e+01, 1.53298140e+01, 1.65761444e+01,
#        1.79564464e+01, 1.94888745e+01, 2.11943859e+01, 2.30972119e+01,
#        2.52254159e+01, 2.76115531e+01, 3.02934537e+01, 3.33151524e+01,
#        3.67279963e+01, 4.05919642e+01, 4.49772448e+01, 4.99661246e+01,
#        5.56552534e+01, 6.21583669e+01, 6.96095673e+01, 7.81672818e+01,
#        8.80190545e+01, 9.93873554e+01, 1.12536644e+02, 1.27781979e+02,
#        1.45499535e+02, 1.66139501e+02, 1.90241922e+02, 2.18456249e+02,
#        2.51565530e+02, 2.90516468e+02, 3.36456947e+02, 3.90783111e+02,
#        4.55198805e+02, 5.31791144e+02, 6.23127464e+02, 7.32381033e+02,
#        8.63496244e+02, 1.02140926e+03, 1.21234871e+03, 1.44425517e+03,
#        1.72738270e+03, 2.07518696e+03, 2.50567553e+03, 3.04351276e+03,
#        3.72334646e+03, 4.59501093e+03, 5.73114399e+03, 7.23595897e+03,
#        9.24554158e+03, 1.18815181e+04, 1.50566714e+04, 1.80466538e+04])

# %%
plt.plot(urang, gsp)
plt.plot(urang, gsp1)
plt.xlabel('potentail strength (u)')
plt.ylabel('ground state minimum')
plt.show()

# %%
plt.plot(urang, gsp)
plt.plot(urang, gsp1)
plt.plot(urang, gsp2)
plt.plot(urang, gsp3)
plt.plot(urang, gsp4)
plt.plot(urang, gsp5)
plt.plot(urang, gsp6)
plt.plot(urang, gsp7)
plt.xlabel('potentail strength (u)')
plt.ylabel('ground state minimum')
plt.show()

# %%
xx=[s[i] for i in range(N)]

for u in urang:
    color1=matplotlib.colors.to_hex((u/10,u/10,u/10))
    plt.plot(xx, [ math.exp(-u*s[i]**2) for i in range(N)],color = color1)
plt.xlabel('x')
plt.xlim([-5, 5])
plt.ylabel('Potential Energy')
plt.title('black-u=10,white-u=0')
plt.show()

# %% [markdown]
# This is strange, because I was assuming that we will have kind of uniformly seperated energy level, but they are repeating with two closly sperated energy level. Why?
# Also we have higher energy for deeper well. does it mean more crazy electron as we have narrower potential?

# %% [markdown]
# # Test SHO potential with higher state?

# %%
N=10
n = list(range(0, N))
v = np.zeros(N)
h = np.zeros((N,N))
o = np.zeros((N,N))


gsp=[]
gsp1=[]
gsp2=[]
gsp3=[]
gsp4=[]
gsp5=[]
gsp6=[]
gsp7=[]

for i in n:
    v[i] = (i+1)/1

for i in n:
    for j in n:
        vpv = v[i]+v[j]
        vmv = v[i]*v[j]
        #print(ss)
        o[i][j] = (2*(vmv**0.5)/vpv)**0.5
        oo=(2*(vmv**0.5)/vpv)**0.5
        t = 0.5*2*vmv/vpv*oo
        p = 0.5*(1/vpv)*oo
        h[i][j] = t + p
#print(h) 
#eigvals, eigvecs = np.linalg.eigh(h)
eigvals, eigvecs = la.eigh(h,o)

eigvals
# Out:
# array([  0.70749672,   3.60202043,   7.23629091,  12.84849316,
#         21.27814016,  33.2675883 ,  49.81525683,  72.4688164 ,
#        104.03759203, 151.3954375 ])
